# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('ORIGINAL-DATASET.csv')

# %%
df
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %%
df.sort_values(by='Year', ascending=True)
# Out:
#                 State  Year      Type_code                           Type  \
# 0       A & N Islands  2001         Causes             Illness (Aids/STD)
# 13203         Mizoram  2001         Causes                   Unemployment
# 13202         Mizoram  2001         Causes    Professional/Career Problem
# 13201         Mizoram  2001         Causes                   Love Affairs
# 13200         Mizoram  2001         Causes                         Cancer
# ...               ...   ...            ...                            ...
# 224315        Gujarat  2012  Means_adopted  By Jumping from (Other sites)
# 224314        Gujarat  2012  Means_adopted                     By Hanging
# 224313        Gujarat  2012  Means_adopted      By Consuming Insecticides
# 224320        Gujarat  2012  Means_adopted                    By Drowning
# 237518    West Bengal  2012  Social_Status                  Never Married
#
#         Gender Age_group  Total
# 0       Female      0-14      0
# ...

# %%
Education = df.loc[df['Type_code'] == 'Education_Status']

# %%
Education
# Out:
#                 State  Year         Type_code                     Type  \
# 260     A & N Islands  2001  Education_Status                  Diploma
# 261     A & N Islands  2001  Education_Status             No Education
# 262     A & N Islands  2001  Education_Status  Post Graduate and Above
# 263     A & N Islands  2001  Education_Status                   Middle
# 264     A & N Islands  2001  Education_Status                 Graduate
# ...               ...   ...               ...                      ...
# 237234    West Bengal  2012  Education_Status                  Primary
# 237235    West Bengal  2012  Education_Status             No Education
# 237236    West Bengal  2012  Education_Status                   Middle
# 237237    West Bengal  2012  Education_Status                 Graduate
# 237238    West Bengal  2012  Education_Status    Matriculate/Secondary
#
#         Gender Age_group  Total
# 260     Female    0-100+      0
# 261     Female    0-100+      4
# ...

# %%
Professional = df.loc[df['Type_code'] == 'Professional_Profile']

# %%
Professional
# Out:
#                 State  Year             Type_code  \
# 436     A & N Islands  2001  Professional_Profile
# 437     A & N Islands  2001  Professional_Profile
# 438     A & N Islands  2001  Professional_Profile
# 439     A & N Islands  2001  Professional_Profile
# 440     A & N Islands  2001  Professional_Profile
# ...               ...   ...                   ...
# 237504    West Bengal  2012  Professional_Profile
# 237505    West Bengal  2012  Professional_Profile
# 237506    West Bengal  2012  Professional_Profile
# 237507    West Bengal  2012  Professional_Profile
# 237508    West Bengal  2012  Professional_Profile
#
#                                 Type  Gender Age_group  Total
# 436                   Retired Person  Female      0-14      0
# 437                       Unemployed  Female      0-14      0
# 438        Public Sector Undertaking  Female      0-14      0
# 439                Service (Private)  Female      0-14      0
# ...

# %%
Social = df.loc[df['Type_code'] == 'Social_Status']

# %%
Social
# Out:
#                 State  Year      Type_code             Type  Gender Age_group  \
# 552     A & N Islands  2001  Social_Status          Married  Female    0-100+
# 553     A & N Islands  2001  Social_Status        Seperated  Female    0-100+
# 554     A & N Islands  2001  Social_Status  Widowed/Widower  Female    0-100+
# 555     A & N Islands  2001  Social_Status         Divorcee  Female    0-100+
# 556     A & N Islands  2001  Social_Status    Never Married  Female    0-100+
# ...               ...   ...            ...              ...     ...       ...
# 237514    West Bengal  2012  Social_Status        Seperated    Male    0-100+
# 237515    West Bengal  2012  Social_Status  Widowed/Widower    Male    0-100+
# 237516    West Bengal  2012  Social_Status          Married    Male    0-100+
# 237517    West Bengal  2012  Social_Status         Divorcee    Male    0-100+
# 237518    West Bengal  2012  Social_Status    Never Married    Male    0-100+
#
#         Total
# 552        38
# ...

# %%
# Education.to_csv('Education.csv', index=False)
# Professional.to_csv('Professional.csv', index=False)
# Social.to_csv('Social.csv', index=False)

# %%
Social
# Out:
#                 State  Year      Type_code             Type  Gender Age_group  \
# 552     A & N Islands  2001  Social_Status          Married  Female    0-100+
# 553     A & N Islands  2001  Social_Status        Seperated  Female    0-100+
# 554     A & N Islands  2001  Social_Status  Widowed/Widower  Female    0-100+
# 555     A & N Islands  2001  Social_Status         Divorcee  Female    0-100+
# 556     A & N Islands  2001  Social_Status    Never Married  Female    0-100+
# ...               ...   ...            ...              ...     ...       ...
# 237514    West Bengal  2012  Social_Status        Seperated    Male    0-100+
# 237515    West Bengal  2012  Social_Status  Widowed/Widower    Male    0-100+
# 237516    West Bengal  2012  Social_Status          Married    Male    0-100+
# 237517    West Bengal  2012  Social_Status         Divorcee    Male    0-100+
# 237518    West Bengal  2012  Social_Status    Never Married    Male    0-100+
#
#         Total
# 552        38
# ...

# %%
grp = Social.groupby('Year')

# %%
for group in grp:
    print(group)
# Out:
# (2001,                State  Year      Type_code             Type  Gender Age_group  \
# 552    A & N Islands  2001  Social_Status          Married  Female    0-100+
# 553    A & N Islands  2001  Social_Status        Seperated  Female    0-100+
# 554    A & N Islands  2001  Social_Status  Widowed/Widower  Female    0-100+
# 555    A & N Islands  2001  Social_Status         Divorcee  Female    0-100+
# 556    A & N Islands  2001  Social_Status    Never Married  Female    0-100+
# ...              ...   ...            ...              ...     ...       ...
# 19792    West Bengal  2001  Social_Status          Married    Male    0-100+
# 19793    West Bengal  2001  Social_Status         Divorcee    Male    0-100+
# 19794    West Bengal  2001  Social_Status  Widowed/Widower    Male    0-100+
# 19795    West Bengal  2001  Social_Status    Never Married    Male    0-100+
# 19796    West Bengal  2001  Social_Status        Seperated    Male    0-100+
#
#        Total
# 552       38
# ...

# %%
df = grp.get_group(2001) 

print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
