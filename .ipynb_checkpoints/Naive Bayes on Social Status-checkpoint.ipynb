# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # NAIVE BAYES ON SOCIAL STATUS

# %%
ds = pd.read_csv("Social_Status.csv")
ds
# Out:
#            State  Year      Type_code             Type  Gender Age_group  \
# 0    West Bengal  2001  Social_Status        Seperated  Female    0-100+
# 1    West Bengal  2001  Social_Status  Widowed/Widower  Female    0-100+
# 2    West Bengal  2001  Social_Status          Married  Female    0-100+
# 3    West Bengal  2001  Social_Status         Divorcee  Female    0-100+
# 4    West Bengal  2001  Social_Status    Never Married  Female    0-100+
# ..           ...   ...            ...              ...     ...       ...
# 115  West Bengal  2012  Social_Status        Seperated    Male    0-100+
# 116  West Bengal  2012  Social_Status  Widowed/Widower    Male    0-100+
# 117  West Bengal  2012  Social_Status          Married    Male    0-100+
# 118  West Bengal  2012  Social_Status         Divorcee    Male    0-100+
# 119  West Bengal  2012  Social_Status    Never Married    Male    0-100+
#
#      Total
# 0      175
# 1      435
# 2     3557
# 3      175
# 4     1853
# ..     ...
# 115    149
# 116    233
# 117   5451
# 118    189
# 119   2658
#
# [120 rows x 7 columns]

# %%
ds = ds.drop(['State','Year','Type_code','Age_group'],axis='columns')
ds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-e130d123a2ab> in <module>
# ----> 1 ds = ds.drop(['Unnamed: 0','State','Year','Type_code','Age_group'],axis='columns')
#       2 ds
#
# c:\users\nivedita biswas\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# c:\users\nivedita biswas\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# c:\users\nivedita biswas\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# c:\users\nivedita biswas\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
X = ds.drop(['Gender'],axis = 'columns')
Y = ds.Gender

# %%
from sklearn.model_selection import train_test_split 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, Y, test_size=0.1)

# %%
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB() 
gnb.fit(X_train1, y_train1)

# %%
y_pred = gnb.predict(X_test1)
from sklearn import metrics 
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test1, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 75.0
