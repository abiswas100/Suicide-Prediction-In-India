# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # NAIVE BAYES ON SOCIAL STATUS

# %%
ds = pd.read_csv("Social_Status.csv")
ds
# Out:
#            State  Year      Type_code             Type  Gender Age_group  \
# 0    West Bengal  2001  Social_Status        Seperated  Female    0-100+
# 1    West Bengal  2001  Social_Status  Widowed/Widower  Female    0-100+
# 2    West Bengal  2001  Social_Status          Married  Female    0-100+
# 3    West Bengal  2001  Social_Status         Divorcee  Female    0-100+
# 4    West Bengal  2001  Social_Status    Never Married  Female    0-100+
# ..           ...   ...            ...              ...     ...       ...
# 115  West Bengal  2012  Social_Status        Seperated    Male    0-100+
# 116  West Bengal  2012  Social_Status  Widowed/Widower    Male    0-100+
# 117  West Bengal  2012  Social_Status          Married    Male    0-100+
# 118  West Bengal  2012  Social_Status         Divorcee    Male    0-100+
# 119  West Bengal  2012  Social_Status    Never Married    Male    0-100+
#
#      Total
# 0      175
# 1      435
# 2     3557
# 3      175
# 4     1853
# ..     ...
# 115    149
# 116    233
# 117   5451
# 118    189
# 119   2658
#
# [120 rows x 7 columns]

# %%
ds = ds.drop(['State','Year','Type_code','Age_group'],axis='columns')
ds
# Out:
#                 Type  Gender  Total
# 0          Seperated  Female    175
# 1    Widowed/Widower  Female    435
# 2            Married  Female   3557
# 3           Divorcee  Female    175
# 4      Never Married  Female   1853
# ..               ...     ...    ...
# 115        Seperated    Male    149
# 116  Widowed/Widower    Male    233
# 117          Married    Male   5451
# 118         Divorcee    Male    189
# 119    Never Married    Male   2658
#
# [120 rows x 3 columns]

# %%
X = ds.drop(['Gender'],axis = 'columns')
Y = ds.Gender

# %%
from sklearn.model_selection import train_test_split 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, Y, test_size=0.1)

# %%
X_train1
# Out:
#                 Type  Total
# 119    Never Married   2658
# 117          Married   5451
# 49           Married   6010
# 41     Never Married   1137
# 30   Widowed/Widower    316
# ..               ...    ...
# 33          Divorcee     94
# 108    Never Married   2973
# 31     Never Married   1270
# 53           Married   4967
# 66           Married   5637
#
# [108 rows x 2 columns]

# %%
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB() 
gnb.fit(X_train1, y_train1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d0306c29abe9> in <module>
#       1 from sklearn.naive_bayes import GaussianNB
#       2 gnb = GaussianNB()
# ----> 3 gnb.fit(X_train1, y_train1)
#
# c:\users\nivedita biswas\appdata\local\programs\python\python37\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     206         y = column_or_1d(y, warn=True)
#     207         return self._partial_fit(X, y, np.unique(y), _refit=True,
# --> 208                                  sample_weight=sample_weight)
#     209
#     210     def _check_X(self, X):
#
# c:\users\nivedita biswas\appdata\local\programs\python\python37\lib\site-packages\sklearn\naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     357         self : object
#     358         """
# --> 359         X, y = check_X_y(X, y)
#     360         if sample_weight is not None:
#     361             sample_weight = _check_sample_weight(sample_weight, X)
#
# c:\users\nivedita biswas\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# --> 755                     estimator=estimator)
#     756     if multi_output:
#     757         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# c:\users\nivedita biswas\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# c:\users\nivedita biswas\appdata\local\programs\python\python37\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Never Married'

# %%
y_pred = gnb.predict(X_test1)
from sklearn import metrics 
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test1, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 75.0
